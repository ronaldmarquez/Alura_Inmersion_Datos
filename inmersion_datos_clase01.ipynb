# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldmarquez/Alura_Inmersion_Datos/blob/main/inmersion_datos_clase01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. comprometerse con los estudios
# 2. realizar los ejercicios
# 3. reservar el espacio y tiempo
# 4. compartir todo lo que aprendimos

# %% [markdown]
# data set = base de datos

# %%
from  google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1. habilitamos la opción de tener conectado nuestro Drive al colab
# 2. podemos verificar en la parte izquierda

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# 1. trajimos la biblioteca panda y la renombramos como "pd" ya que se le suele conocer así
# 2. importamos el archivo csv de inmuebles
# 3. para estar seguro de que ibamos bien imprimimos la cabecera que te imprime las 5 primeras filas

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %% [markdown]
# 1. te muestra filas y columnas sin contar el ìndice

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 443   Apartamento             Apartamento en venta en Kennedy             3
# 777   Apartamento             Apartamento en venta en Usaquén             2
# 4343  Apartamento            Apartamento en venta en Cedritos             2
# 5818  Apartamento            Apartamento en venta en Fontibón             1
# 1263         Casa         Casa en venta en Zona Noroccidental             3
# 1753  Apartamento            Apartamento en venta en Cedritos             1
# 3451         Casa                       Casa en venta en Bosa             3
# 3007  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1389  Apartamento             Apartamento en venta en Usaquén             3
# 4014         Casa         Casa en venta en Zona Noroccidental             5
#
#       Banos  Area              Barrio                                 UPZ  \
# ...

# %% [markdown]
# 1. creo una lista (me parece)
# 2. crea un diccionario para cambiar palabras que puede causar problemas en el futuro
# 3. renombra algunas columnas
# 4. trae 10 ejemplos de 10 filas random

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# ¿que es UPZ?
# Unidades de planeación zonal

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# es como que busca un valor, es una forma de filtrar
# - tener en cuenta que comienta con el indice 0

# %%
inmuebles.iloc[300:303]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000

# %% [markdown]
# nos devuelve todo ese rango de registros

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300:310]
# Out:
# 300      $ 116.100.000
# 301      $ 980.000.000
# 302      $ 237.000.000
# 303      $ 320.000.000
# 304      $ 530.000.000
# 305      $ 503.000.000
# 306      $ 117.000.000
# 307    $ 1.300.000.000
# 308      $ 477.000.000
# 309      $ 450.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#                      Tipo                                    Descripcion  \
# 3937          Apartamento                Apartamento en venta en Usaquén
# 2616          Apartamento                Apartamento en venta en Usaquén
# 8762  Oficina/Consultorio  Oficina/Consultorio en venta en Santa Barbara
# 3999          Apartamento                Apartamento en venta en Usaquén
# 188           Apartamento               Apartamento en venta en Cedritos
# ...                   ...                                            ...
# 3600          Apartamento               Apartamento en venta en Cedritos
# 5984          Apartamento               Apartamento en venta en La Salle
# 1204          Apartamento              Apartamento en venta en Chapinero
# 4377          Apartamento         Apartamento en venta en Barrios Unidos
# 3022          Apartamento     Apartamento en venta en Zona Noroccidental
#
#       Habitaciones  Banos  Area              Barrio  \
# ...

# %%
inmuebles.Barrio=='Santa Barbara'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum(inmuebles.Barrio=='Chico Reservado')
# Out:
# 225

# %%
inmuebles_chico =(inmuebles.Barrio=='Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado= inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio=inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.sample(5).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/index.html

# %% [markdown]
# **Desafio**
# 1. promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
# 2. consultar otros datos estadisticos, conteo, mediana, valores mínimos y máximos

# %%
data_frame=pd.DataFrame(inmuebles)

# %%
promedio_barrio=data_frame.groupby('Barrio')['Area'].mean()

# %%
print(promedio_barrio)
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %%
promedio_barrio=promedio_barrio.sort_values(ascending=False)

# %%
promedio_barrio.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000
